# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm as tqdm

# %%
set_t = 'testing'

img_indexes = np.load(f'../../sorted_data/LFP/{set_t}/index_{set_t}_LFP.npy').astype(np.int)
img_dir = f'../../DeepMonkey/Data/Stimuli/Processed/{set_t.capitalize()}/'

# nn_training = np.load('../../sorted_data/LFP/training/LFP_training_data32_normalized_fast.npy')
# nn_testing = np.load('../../sorted_data/LFP/testing/LFP_testing_data32_normalized.npy')

# %%
img_indexes
# Out:
# array([ 0,  0,  0, ..., 99, 99, 99])

# %%
cropped_img = []
for i in tqdm(range((100))):
    t = plt.imread(img_dir+str(i).zfill(4)+'.png')
    
    
    img_width = t.shape[0]
    left_e = int((img_width / 100 * 27.5))
    right_s = int(img_width - (img_width/100*32.5))

    img_height = t.shape[1]
    top_e = int((img_height / 100 * 27.5))
    bot_s = int(img_height - (img_height/100*32.5))
    
    cropped_t = t[left_e:right_s, top_e:bot_s, :]
#     plt.figure(figsize = (10,10))
#     plt.subplot(1,3,1)
#     plt.imshow(t)
#     plt.subplot(1,2,2)
#     plt.imshow(cropped_t)

    cropped_img.append(cropped_t)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 38.11it/s]

# %%
cropped_img = np.stack(cropped_img)

# %%
np.save('cropped_images_testing.npy', cropped_img)

# %%
cropped_gaus = np.load('multivariate_gaussians240_cropped.npy')
old_gaus = np.load('multivariate_gaussians240_norm.npy')

# %%
N = 240


X = np.linspace(-2, 6, N)
Y = np.linspace(-6, 2, N)
X, Y = np.meshgrid(X, Y)
fig = plt.figure(figsize=(5,5))
plt.xlabel('x')
plt.ylabel('y')
for i in tqdm(cropped_gaus):

    ax = fig.gca(projection='3d')
    ax.plot_surface(X, Y, i, rstride=3, cstride=3, linewidth=1, antialiased=True,

                    cmap=cm.viridis)
    cset = ax.contourf(X, Y, i, zdir='z', offset=-0.0001, cmap=cm.viridis)
# ax.set_zlim(-0.0001,i.max())
# ax.set_zticks([])
plt.show()
# Out:
#   0%|          | 0/192 [00:00<?, ?it/s]/home/lynnle/miniconda/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.
#   if sys.path[0] == '':
# /home/lynnle/miniconda/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# 100%|██████████| 192/192 [00:55<00:00,  3.28it/s]

# %%
ax.set_zlim(-0.0001,i.max())
ax.set_zticks([])
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.contour(cropped_gaus[57], levels = 0, cmap='Blues')

# %%
test_i = 0

plt.figure(figsize=(10,10))

plt.ylabel('y')
plt.xlabel('x')
for i in cropped_gaus:
    plt.contour(i, levels = 0, cmap = 'Reds', alpha = 1)
    
# plt.contour(cropped_gaus[2], cmap = 'Reds')
# plt.contour(cropped_gaus[70], cmap ='Reds')
plt.gca()
plt.show()

# %%
for i in range(len(x_batch)):
    t = x_batch[i]
    
    img_width = t.shape[0]
    left_e = int((img_width / 100 * 27.5))
    right_s = int(img_width - (img_width/100*32.5))

    img_height = t.shape[1]
    top_e = int((img_height / 100 * 27.5))
    bot_s = int(img_height - (img_height/100*32.5))
    
    cropped_t = t[left_e:right_s, top_e:bot_s, :]
    plt.figure(figsize = (10,10))
    plt.subplot(1,3,1)
    plt.imshow(t)
    plt.subplot(1,3,2)
    plt.imshow(cropped_t)
    plt.subplot(1,3,3)
    plt.imshow(sum([cropped_t,gaus]), cmap = 'jet')

# %%
N = 240
X = np.linspace(-2, 6, N)
Y = np.linspace(-6, 2, N)
X, Y = np.meshgrid(X, Y)

Z = sum(gaussian_list)
Z = Z/Z.sum()


fig = plt.figure(figsize=(5,5))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, rstride=3, cstride=3, linewidth=1, antialiased=True,

                cmap=cm.viridis)

cset = ax.contourf(X, Y, Z, zdir='z', offset=-0.01, cmap=cm.viridis)

#     ax.view_init(40, -90)
ax.view_init()
ax.set_zlim(-0.01,Z.max())
ax.set_zticks([])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
gaus = sum(gaussian_list).repeat(3).reshape(240,240,3)

# %%
gaus = (gaus * 1/gaus.max())

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
